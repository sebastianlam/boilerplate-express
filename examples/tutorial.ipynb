# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://www.pepy.tech/projects/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
# %pip install ultralytics
import ultralytics, torch
ultralytics.checks()
from ultralytics import YOLO

from google.colab import drive
drive.mount('/content/drive')
# directory setups
# %cd /content/drive/MyDrive/abc/
# print cwd
# %pwd
# %ls -lah

# # Load a model
# model = YOLO('yolo11n.yaml')  # build a new model from scratch
# model = YOLO('yolo11n.pt')  # load a pretrained model (recommended for training)

# # Use the model
# results = model.train(data='coco8.yaml', epochs=3)  # train the model
# results = model.val()  # evaluate model performance on the validation set
# results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
# results = model.export(format='onnx')  # export the model to ONNX format
# # Load YOLO11n, train it on COCO128 for 3 epochs and predict an image with it

# model = YOLO('yolo11n.pt')  # load a pretrained YOLO detection model
# model.train(data='coco8.yaml', epochs=3)  # train the model
# model('https://ultralytics.com/images/bus.jpg')  # predict on an image
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.6/112.6 GB disk)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive
# ls: aacmp: No such file or directory
# ls: computer-vision: No such file or directory
# ls: raw-videos: No such file or directory
# ls: sports-vision: No such file or directory
# total 1.8G
# -rw------- 1 root root 626K Feb 23  2020  00.3dm
# -rw------- 1 root root 1.9K May 22  2023  2023-05-22T16_36_59.257Z.Desktop.md
# -rw------- 1 root root 2.5K May 22  2023  2023-05-22T16_39_19.022Z.Desktop.md
# -rw------- 1 root root 2.5K May 22  2023  2023-05-22T16_41_09.544Z.Desktop.md
# -rw------- 1 root root 1.4K May 26  2023  2023-05-26T15_33_48.241Z.Desktop.md
# -rw------- 1 root root 1.4K May 26  2023  2023-05-26T15_34_29.338Z.Desktop.md
# -rw------- 1 root root 1.5K May 26  2023  2023-05-26T15_35_21.022Z.Desktop.md
# -rw------- 1 root root 1.5K May 26  2023  2023-05-26T15_35_41.475Z.Desktop.md
# -rw------- 1 root root 2.3K May 26  2023  2023-05-26T16_59_15.182Z.Desktop.md
# -rw------- 1 root root 2.3K May 26  2023  2023-05-26T17_00_16.993Z.Desktop.md
# -rw------- 1 root root 146K Jul 19 23:07 '4844310 (1).pdf'
# -rw------- 1 root root 146K Jul 19 23:07  4844310.pdf
# lrw------- 1 root root    0 Apr 25  2023  aacmp -> /content/drive/.shortcut-targets-by-id/1-7gyT0gumTVYpZ6LQyuQjMOUyJ7aLxWu/aacmp/
# drwx------ 2 root root 4.0K Apr  5  2024  abc/
# drwx------ 2 root root 4.0K Nov 13 16:03 'Admission past paper'/
# drwx------ 2 root root 4.0K Jan  7  2020 'ad_with _subs'/
# drwx------ 2 root root 4.0K Jul  1 13:13  AI/
# drwx------ 2 root root 4.0K Mar  1  2020  ALink/
# -rw------- 1 root root 707M Apr 14  2022  Archive.zip
# -rw------- 1 root root  182 Sep 24 14:11 'backup codes.gdoc'
# drwx------ 2 root root 4.0K Mar 19  2019  BDES/
# -rw------- 1 root root  182 Nov  9  2023  beeper.gdoc
# -rw------- 1 root root  182 Mar  7  2023 'B Personal statement - Ansen Lam.gdoc'
# -rw------- 1 root root  54M Jul 31  2020 'Bus Shelter (1).3dm'
# -rw------- 1 root root  32M Jul 31  2020 'Bus Shelter (2).3dm'
# -rw------- 1 root root  54M Jul 31  2020 'Bus Shelter.3dm'
# drwx------ 2 root root 4.0K Jun  4  2024  Calc/
# drwx------ 2 root root 4.0K May 31  2018  Career/
# drwx------ 2 root root 4.0K Feb  1  2023 'Colab Notebooks'/
# -rw------- 1 root root  30K May 11  2024  COM1028-Coursework_lam_jl03093_6842768.odt
# lrw------- 1 root root    0 Nov  8  2023  computer-vision -> /content/drive/.shortcut-targets-by-id/1T9nAqacU41nrZRuRMReIqNSoYMqZapTL/computer-vision/
# -rw------- 1 root root  17K Apr 16  2021  ConverLetterJIMLAM_UL_2021416.pdf
# -rw------- 1 root root  182 Oct 20  2021 'Copy of Jim Lam.gdoc'
# -rw------- 1 root root  182 Apr  4  2023 'Copy of Jim Statement.gdoc'
# -rw------- 1 root root  69K Jan  3  2024  coursework-EERD.drawio
# drwx------ 2 root root 4.0K May 20  2024 'DATA STRUCTURES EXAM'/
# drwx------ 2 root root 4.0K May 31  2018  DEBATE/
# drwx------ 2 root root 4.0K Jun 27  2018 'DECACORN STACK'/
# drwx------ 2 root root 4.0K Mar 24  2019  Desktop/
# drwx------ 2 root root 4.0K Nov 13 16:03 'DRIVE backup'/
# -rw------- 1 root root 1.6K Sep 30  2020  edn-to-plist.clj
# -rw------- 1 root root  182 Mar 12  2024 'Entschuldigung, gibt es mein Cafe.gdoc'
# -rw------- 1 root root  28K Oct 24  2023  FlimDB
# drwx------ 2 root root 4.0K Mar  1  2020  french/
# -rw------- 1 root root 384M Mar 13  2024  Germanmulticam.mp4
# -rw------- 1 root root  206 Oct 31  2023  github-recovery-codes.txt
# drwx------ 2 root root 4.0K Jun 29  2019 'Google Photos'/
# drwx------ 2 root root 4.0K Dec  3  2022 'Graduation traces'/
# -rw------- 1 root root  182 Dec  5  2023 'Group 071.gdoc'
# -rw------- 1 root root 155K Nov 10  2018  haskell-cheatsheet.pdf
# drwx------ 2 root root 4.0K Mar  1  2020  HKDSE/
# -rw------- 1 root root 6.3M Mar 16  2020 'Human Deccication (1).pdf'
# -rw------- 1 root root 5.2M Mar  9  2020 'Human Deccication.indd'
# -rw------- 1 root root 8.0M Mar 16  2020 'Human Deccication.pdf'
# -rw------- 1 root root 2.8M Apr 18  2024  IMG_4951.PNG
# -rw------- 1 root root  58M Oct 13 14:34  IMG_8825.png
# -rw------- 1 root root 1.1M Aug 12  2019 'interior design student handbook.pdf'
# -rw------- 1 root root  182 Apr 11  2022  JimLamCV20210416.gdoc
# -rw------- 1 root root  66K Apr 16  2021  JimLamCV20210416.pdf
# -rw------- 1 root root  182 Mar 14  2023 'Jim Statement.gdoc'
# -rw------- 1 root root  11M Dec 12  2020  Jonathan-S-Golan-auth-The-Linear-Algebra-a-Beginning-Graduate-Student-Ought-to-Know-Springer-Netherlands-2012.pdf
# -rw------- 1 root root 141M Mar 17  2020  JOnny.pdf
# -rw------- 1 root root 555K Sep 15  2021  Master_Thesis_final.DOCX
# -rw------- 1 root root  182 Oct 25  2022 'Mein Lieblingstagebuch:.gdoc'
# drwx------ 2 root root 4.0K Nov 13 16:03  motion.source/
# -rw------- 1 root root 108M Oct  1  2020  motion.source.zip
# drwx------ 2 root root 4.0K Apr 18  2024  Notes/
# -rw------- 1 root root 4.1M Aug  1  2020  ohch.3dm
# -r-------- 1 root root  21M Aug 20  2017  os3.pdf
# -rw------- 1 root root 6.3M Mar 16  2020  Pond.pdf
# drwx------ 2 root root 4.0K Mar  1  2020  Portfolio/
# -rw------- 1 root root 2.9M Jul 24  2020 'Preview from mid level.png'
# -rw------- 1 root root 4.4M Jul 25  2020  Process.3dm
# -rw------- 1 root root  182 Sep  4  2023 'Prospective properties.gsheet'
# lrw------- 1 root root    0 Jan 12  2024  raw-videos -> /content/drive/.shortcut-targets-by-id/12E54ZCmPT3HGhbbWx600w_fvykHO13iK/raw-videos/
# drwx------ 2 root root 4.0K Mar 17  2020  Refined/
# -rw------- 1 root root  182 Apr 16  2021  Resume.gdoc
# -rw------- 1 root root  182 Mar  1  2020 'Rocket Specs.gsheet'
# drwx------ 2 root root 4.0K Jan 19  2024  ROOMDAMAGELOG/
# -rw------- 1 root root 739K Nov 18 23:10  RPO3UCubeSatReqsPrelim.docx
# -rw------- 1 root root 184M Mar 12  2024  sample.mp4
# drwx------ 2 root root 4.0K Mar  1  2020  SONA/
# lrw------- 1 root root    0 Jan 19  2024  sports-vision -> /content/drive/.shortcut-targets-by-id/11gyk2GZpCiiqu7ybRPNd_BQV_n3VEPY9/sports-vision/
# drwx------ 2 root root 4.0K May 31  2018  SSGC/
# -rw------- 1 root root 455K Mar  8  2020 'stadium (1).3dm'
# -rw------- 1 root root 319K Mar  8  2020 'stadium (1).3dmbak'
# -rw------- 1 root root 3.9M Jan 19  2024  surreyID.JPG
# -rw------- 1 root root  182 Mar 22  2023 'Take some ideas from GPT-4:.gdoc'
# -rw------- 1 root root 8.7M Aug  1  2020  temp.3dm
# -rw------- 1 root root 4.1M Jul 24  2020 'temp copy.3dm'
# drwx------ 2 root root 4.0K Mar  1  2020 'Tick Tsui'/
# -rw------- 1 root root  182 May 28  2020 'To Kill A Mockingbird - Full Text PDF.gdoc'
# -rw------- 1 root root 492K May 28  2020 'To Kill A Mockingbird - Full Text PDF.pdf'
# -rw------- 1 root root 8.5M Jul 23  2020  trial.3dm
# -rw------- 1 root root 2.7M Jul 22  2020  Untitled.3dm
# -rw------- 1 root root  182 Nov 16  2023 'Untitled document (1).gdoc'
# -rw------- 1 root root  182 Aug 25  2023 'Untitled document (2).gdoc'
# -rw------- 1 root root  182 Mar 19  2023 'Untitled document (3).gdoc'
# -rw------- 1 root root  182 Mar  2  2023 'Untitled document (4).gdoc'
# -rw------- 1 root root  182 Apr  2  2022 'Untitled document (5).gdoc'
# -rw------- 1 root root  182 Sep  5  2020 'Untitled document (6).gdoc'
# -rw------- 1 root root  182 Mar  9  2020 'Untitled document (7).gdoc'
# -rw------- 1 root root  182 Dec 22  2018 'Untitled document (8).gdoc'
# -rw------- 1 root root  182 Sep  1 17:29 'Untitled document.gdoc'
# -rw------- 1 root root  182 Oct 10  2022 'Untitled form.gform'
# -rw------- 1 root root  182 Oct 24  2023 'Untitled spreadsheet.gsheet'
# drwx------ 2 root root 4.0K Sep 17  2023 'U of Surrey Year 1'/
# -rw------- 1 root root  182 Mar 23  2022 'Writing boost.gdoc'
# drwx------ 2 root root 4.0K Mar 11  2020 'YR 2 studio'/
